# %%
# Create dependencies
import json
import tweepy
import pandas as pd
import numpy as np
import time
import seaborn as ns
import matplotlib.pyplot as plt
import textblob
from collections import OrderedDict
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Import sentiment analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Setup Tweepy API Authentification
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Get tweepy rate limits
#api.rate_limit_status()

# %%
# Target user accounts
target_users = ("@BBCNews", "@CBSNews", "@CNN", "@FoxNews", "@nytimes")

# Variable for holding the oldest tweet
oldest_tweet = ""

# Loop through each user
for user in target_users:
    
    # Variables for holding sentiments
    compound_list = []
    positive_list = []
    neutral_list = []
    negative_list = []
    
    # Loop through 5 pages of tweets for a total of 100 tweets
    for x in range(5):

        # Get all tweets from the users home feed
        public_tweets = api.user_timeline(user)
                                          
        # Loop through all tweets
        for tweet in public_tweets:

            # Run Vader Analysis on each tweet
            compound = analyzer.polarity_scores(tweet['text'])["compound"]
            pos = analyzer.polarity_scores(tweet['text'])["pos"]
            neu = analyzer.polarity_scores(tweet['text'])["neu"]
            neg = analyzer.polarity_scores(tweet['text'])["neg"]

            # Add each value to the appropriate array
            compound_list.append(compound)
            positive_list.append(pos)
            negative_list.append(neg)
            neutral_list.append(neu)

    # Print the Averages for each user
    print("")
    print("User: %s" % user)
    print("Compound: %s" % np.mean(compound_list))
    print("Positive: %s" % np.mean(positive_list))
    print("Neutral: %s" % np.mean(neutral_list))
    print("Negative: %s" % np.mean(negative_list))
# Out:
# User: @BBCNews
# Compound: -0.09213500000000002
# Positive: 0.043800000000000006
# Neutral: 0.8560999999999999
# Negative: 0.1001
#
# User: @CBSNews
# Compound: 0.028430000000000004
# Positive: 0.06924999999999999
# Neutral: 0.86685
# Negative: 0.06385
#
# User: @CNN
# Compound: 0.06890500000000001
# Positive: 0.0682
# Neutral: 0.8791499999999999
# Negative: 0.0526
#
# User: @FoxNews
# Compound: -0.09878499999999998
# Positive: 0.0385
# Neutral: 0.8635499999999997
# Negative: 0.09795
#
# User: @nytimes
# Compound: -0.13165000000000002
# Positive: 0.0401
# Neutral: 0.8710000000000001
# Negative: 0.08885000000000001

# %%
# Get 100 most recent tweets
#public_tweets = api.search(target_terms, count=100, result_type="recent")

# %%
# Loop through all tweets
for tweet in public_tweets["statuses"]:
    
    # Run Vader analysis on each score
    compound = analyzer.polarity_scores(tweet["text"])["compound"]
    pos = analyzer.polarity_scores(tweet["text"])["pos"]
    neu = analyzer.polarity_scores(tweet["text"])["neu"]
    neg = analyzer.polarity_scores(tweet["text"])["neg"]

    # Add each value to the corresponding category
    compound_list.append(compound)
    positive_list.append(pos)
    neutral_list.append(neu)
    negative_list.append(neg)

# Print the averages for the responses
print()
print("User: %s" % target_terms)
print("Compound Score: %s" % compound)
print("Positive Score: %s" % pos)
print("Neutral Score: %s" % neu)
print("Negative Score: %s" % neg)
print()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-4e1d588ae541> in <module>()
#       1 # Loop through all tweets
# ----> 2 for tweet in public_tweets["statuses"]:
#       3
#       4     # Run Vader analysis on each score
#       5     compound = analyzer.polarity_scores(tweet["text"])["compound"]
#
# TypeError: list indices must be integers or slices, not str

# %%
# Create dataframe for sentiments
sentiments = OrderedDict([('News Organization', target_terms),
              ('Tweet', tweet),
              ('Tweet Date', ''),
              ('Compound Score', compound),
              ('Positive Score', pos),
              ('Neutral Score', neu),
              ('Negative Score', neg)])

# %%
# View dataframe
sentiments_data=pd.DataFrame.from_dict(sentiments)
sentiments_data
# Out:
#                           News Organization  \
# contributors                       @BBCNews
# coordinates                        @BBCNews
# created_at                         @BBCNews
# entities                           @BBCNews
# favorite_count                     @BBCNews
# favorited                          @BBCNews
# geo                                @BBCNews
# id                                 @BBCNews
# id_str                             @BBCNews
# in_reply_to_screen_name            @BBCNews
# in_reply_to_status_id              @BBCNews
# in_reply_to_status_id_str          @BBCNews
# in_reply_to_user_id                @BBCNews
# in_reply_to_user_id_str            @BBCNews
# is_quote_status                    @BBCNews
# lang                               @BBCNews
# metadata                           @BBCNews
# place                              @BBCNews
# retweet_count                      @BBCNews
# retweeted                          @BBCNews
# source                             @BBCNews
# text                               @BBCNews
# truncated                          @BBCNews
# user                               @BBCNews
#
#                                                                        Tweet  \
# contributors                                                            None
# coordinates                                                             None
# created_at                                    Tue Apr 03 03:24:53 +0000 2018
# entities                   {'hashtags': [], 'symbols': [], 'user_mentions...
# favorite_count                                                             0
# favorited                                                              False
# geo                                                                     None
# id                                                        981009617550561280
# id_str                                                    981009617550561280
# in_reply_to_screen_name                                              BBCNews
# in_reply_to_status_id                                     980979236738686976
# in_reply_to_status_id_str                                 980979236738686976
# in_reply_to_user_id                                                   612473
# in_reply_to_user_id_str                                               612473
# is_quote_status                                                        False
# lang                                                                      en
# metadata                   {'iso_language_code': 'en', 'result_type': 're...
# place                                                                   None
# retweet_count                                                              0
# retweeted                                                              False
# source                     <a href="http://twitter.com/download/android" ...
# text                                            @BBCNews Ban guns... Oh wait
# truncated                                                              False
# user                       {'id': 729669192908214273, 'id_str': '72966919...
#
#                           Tweet Date  Compound Score  Positive Score  \
# contributors                                 -0.5574             0.0
# coordinates                                  -0.5574             0.0
# created_at                                   -0.5574             0.0
# entities                                     -0.5574             0.0
# favorite_count                               -0.5574             0.0
# favorited                                    -0.5574             0.0
# geo                                          -0.5574             0.0
# id                                           -0.5574             0.0
# id_str                                       -0.5574             0.0
# in_reply_to_screen_name                      -0.5574             0.0
# in_reply_to_status_id                        -0.5574             0.0
# in_reply_to_status_id_str                    -0.5574             0.0
# in_reply_to_user_id                          -0.5574             0.0
# in_reply_to_user_id_str                      -0.5574             0.0
# is_quote_status                              -0.5574             0.0
# lang                                         -0.5574             0.0
# metadata                                     -0.5574             0.0
# place                                        -0.5574             0.0
# retweet_count                                -0.5574             0.0
# retweeted                                    -0.5574             0.0
# source                                       -0.5574             0.0
# text                                         -0.5574             0.0
# truncated                                    -0.5574             0.0
# user                                         -0.5574             0.0
#
#                            Neutral Score  Negative Score
# contributors                       0.526           0.474
# coordinates                        0.526           0.474
# created_at                         0.526           0.474
# entities                           0.526           0.474
# favorite_count                     0.526           0.474
# favorited                          0.526           0.474
# geo                                0.526           0.474
# id                                 0.526           0.474
# id_str                             0.526           0.474
# in_reply_to_screen_name            0.526           0.474
# in_reply_to_status_id              0.526           0.474
# in_reply_to_status_id_str          0.526           0.474
# in_reply_to_user_id                0.526           0.474
# in_reply_to_user_id_str            0.526           0.474
# is_quote_status                    0.526           0.474
# lang                               0.526           0.474
# metadata                           0.526           0.474
# place                              0.526           0.474
# retweet_count                      0.526           0.474
# retweeted                          0.526           0.474
# source                             0.526           0.474
# text                               0.526           0.474
# truncated                          0.526           0.474
# user                               0.526           0.474

# %%
# Create plot
#plt.plot(np.range(len(sentiments_pd["Compound"])), sentiments_pd["Compound"], markers="o", linewidth=0.5, alpha=.8)

#plt.title("Sentiment Analysis of Tweets (%s) for %s" % (time.strftime("%x"), target_terms))
#plt.ylabel(" ")
#plt.xlabel(" ")
#plt.show()
